# %%
import numpy as np
import pandas as pd
from pyspark import SparkContext
from pyspark.sql import SparkSession
import pyspark as spark
from pyspark.ml.feature import StringIndexer,IndexToString
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.feature import StandardScaler
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
# from pyspark.ml.feature import IDF
# from pyspark.ml.feature import DCT
# from pyspark.ml.feature import PolynomialExpansion
# from pyspark.ml.feature import ChiSqSelector
from pyspark.ml import Pipeline
import itertools as it
import pyspark.sql.functions as f

# %%
# TODO 1. rename column names containing '.' (GS1-279B7.1, GS1-600G8.3 CAND1.11, HY.1)
#      2. read csv sep = ',' for cpv final matrix

# %%
spark = SparkSession.builder.appName("DiseaseApp").getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.1.115:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.3.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>DiseaseApp</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# %%info

# %%
seed = 0

# %%
SparkContext.setSystemProperty('spark.executor.memory', '2g')
#sc._conf.getAll()

# %%
# helper function to get all stored variables
def list_dataframes():
    from pyspark.sql import DataFrame
    return [k for (k, v) in globals().items() if isinstance(v, DataFrame)]

# %%
def getTrainingMetrics(trainingSummary,printout=True):
    # for multiclass, we can inspect metrics on a per-label basis
#     print("False positive rate by label:")
#     for i, rate in enumerate(trainingSummary.falsePositiveRateByLabel):
#         print("label %d: %s" % (i, rate))

#     print("True positive rate by label:")
#     for i, rate in enumerate(trainingSummary.truePositiveRateByLabel):
#         print("label %d: %s" % (i, rate))

#     print("Precision by label:")
#     for i, prec in enumerate(trainingSummary.precisionByLabel):
#         print("label %d: %s" % (i, prec))

#     print("Recall by label:")
#     for i, rec in enumerate(trainingSummary.recallByLabel):
#         print("label %d: %s" % (i, rec))

    print("F-measure by label:")
    for i, f in enumerate(trainingSummary.fMeasureByLabel()):
        print("label %d: %s" % (i, f))

    accuracy = trainingSummary.accuracy
    falsePositiveRate = trainingSummary.weightedFalsePositiveRate
    truePositiveRate = trainingSummary.weightedTruePositiveRate
    fMeasure = trainingSummary.weightedFMeasure()
    precision = trainingSummary.weightedPrecision
    recall = trainingSummary.weightedRecall
    if printout is True:
        print("Accuracy: %s\nFPR: %s\nTPR: %s\nF-measure: %s\nPrecision: %s\nRecall: %s"
          % (accuracy, falsePositiveRate, truePositiveRate, fMeasure, precision, recall))
    return {"accuracy": accuracy, "fpr": falsePositiveRate, "tpr": truePositiveRate, "fmeasure": fMeasure, \
            "precision": precision, "recall": recall}

# %%
# read data file
path = 'data/cpv_full_matrix.csv'
df = spark.read.option("maxColumns", 22400).csv(
    path, header=True, sep = ',',mode="DROPMALFORMED",inferSchema=True)

# %%
df = df.toDF(*(c.replace('.', '_') for c in df.columns))

# %%
# df.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- MRPL30: double (nullable = true)
#  |-- PITX3: double (nullable = true)
#  |-- LINC00575: double (nullable = true)
#  |-- NR4A1: double (nullable = true)
#  |-- LINC01105: double (nullable = true)
#  |-- OLFM3: double (nullable = true)
#  |-- TTC23: double (nullable = true)
#  |-- AKIRIN1: double (nullable = true)
#  |-- PECR: double (nullable = true)
#  |-- TBX20: double (nullable = true)
#  |-- NBPF10: double (nullable = true)
#  |-- DHRS7B: double (nullable = true)
#  |-- RFPL4B: double (nullable = true)
#  |-- CAMK4: double (nullable = true)
#  |-- CTXND1: double (nullable = true)
#  |-- MIR4759: double (nullable = true)
#  |-- FBRSL1: double (nullable = true)
#  |-- FAM155A: double (nullable = true)
#  |-- PRSS27: double (nullable = true)
#  |-- LOC101928764: double (nullable = true)
#  |-- CAPN15: double (nullable = true)
#  |-- DHX58: double (nullable = true)
#  |-- FCN2: double (nullable = true)
#  |-- IQCA1: double (nullable = true)
#  |-- FAM92B: double (nullable = true)
#  |-- MPRIP: double (nullable = true)
#  |-- ATXN7L1: double (nullable = true)
#  |-- UPK2: double (nullable = true)
#  |-- PCGF6: double (nullable = true)
#  |-- RRBP1: double (nullable = true)
#  |-- MLF1: double (nullable = true)
#  |-- SPATA2L: double (nullable = true)
#  |-- ARNTL2: double (nullable = true)
#  |-- MYO5C: double (nullable = true)
#  |-- CD109: double (nullable = true)
#  |-- OTP: double (nullable = true)
#  |-- ACTN1: double (nullable = true)
#  |-- CES1P2: double (nullable = true)
#  |-- TSFM: double (nullable = true)
#  |-- LINC02219: double (nullable = true)
#  |-- RCOR3: double (nullable = true)
#  |-- MMP27: double (nullable = true)
#  |-- MORN4: double (nullable = true)
#  |-- RRAS2: double (nullable = true)
#  |-- USO1: double (nullable = true)
#  |-- BTBD16: double (nullable = true)
#  |-- ZNF609: double (nullable = true)
#  |-- LINC01960: double (nullable = true)
#  |-- FAM76A: double (nullable = true)
#  |-- MKS1: double (nullable = true)
#  |-- LOC101929935: double (nullable = true)
#  |-- NANOGNB: double (nullable = true)
#  |-- CHSY1: double (nullable = true)
#  |-- LOC729218: double (nullable = true)
#  |-- MAP3K6: double (nullable = true)
#  |-- SVBP: double (nullable = true)
#  |-- LOC105376398: double (nullable = true)
#  |-- CXCR4: double (nullable = true)
#  |-- SATB1-AS1: double (nullable = true)
#  |-- SNAPC5: double (nullable = true)
#  |-- PKNOX2: double (nullable = true)
#  |-- CLCA2: double (nullable = true)
#  |-- LYL1: double (nullable = true)
#  |-- NFIA-AS2: double (nullable = true)
#  |-- LINC01477: double (nullable = true)
#  |-- CFAP73: double (nullable = true)
#  |-- RHBDD1: double (nullable = true)
#  |-- RABEPK: double (nullable = true)
#  |-- PHF7: double (nullable = true)
#  |-- RPL30: double (nullable = true)
#  |-- ORMDL2: double (nullable = true)
#  |-- BTNL2: double (nullable = true)
#  |-- GEM: double (nullable = true)
#  |-- RBPMS: double (nullable = true)
#  |-- FBXL5: double (nullable = true)
#  |-- WFDC12: double (nullable = true)
#  |-- LOC100288162: double (nullable = true)
#  |-- ARHGAP26: double (nullable = true)
#  |-- LINC01782: double (nullable = true)
#  |-- SLC17A5: double (nullable = true)
#  |-- ADGRL3: double (nullable = true)
#  |-- ASPH: double (nullable = true)
#  |-- HMBS: double (nullable = true)
#  |-- PCDHB7: double (nullable = true)
#  |-- BAX: double (nullable = true)
#  |-- OR1A1: double (nullable = true)
#  |-- SDHAF3: double (nullable = true)
#  |-- LOC105369747: double (nullable = true)
#  |-- RAPGEF2: double (nullable = true)
#  |-- P2RX5-TAX1BP3: double (nullable = true)
#  |-- BCL11B: double (nullable = true)
#  |-- POTEKP: double (nullable = true)
#  |-- ANKRD16: double (nullable = true)
#  |-- TMEM220-AS1: double (nullable = true)
#  |-- CTPS2: double (nullable = true)
#  |-- SRM: double (nullable = true)
#  |-- MATN1: double (nullable = true)
#  |-- NSMCE4A: double (nullable = true)
#  |-- PSMD1: double (nullable = true)
#  |-- OR2T8: double (nullable = true)
#  |-- LINC01248: double (nullable = true)
#  |-- UNG: double (nullable = true)
#  |-- APOBEC3A: double (nullable = true)
#  |-- LINC00308: double (nullable = true)
#  |-- MTHFD2: double (nullable = true)
#  |-- SPDYE10P: double (nullable = true)
#  |-- XPNPEP3: double (nullable = true)
#  |-- TRAM1: double (nullable = true)
#  |-- IL17A: double (nullable = true)
#  |-- CCDC70: double (nullable = true)
#  |-- MTUS2: double (nullable = true)
#  |-- PLA2R1: double (nullable = true)
#  |-- PAXBP1: double (nullable = true)
#  |-- NRL: double (nullable = true)
#  |-- SOX8: double (nullable = true)
#  |-- OR10AG1: double (nullable = true)
#  |-- PPWD1: double (nullable = true)
#  |-- USP25: double (nullable = true)
#  |-- UBE2E4P: double (nullable = true)
#  |-- SNX33: double (nullable = true)
#  |-- IRF8: double (nullable = true)
#  |-- TMEM206: double (nullable = true)
#  |-- ACVR2A: double (nullable = true)
#  |-- SELENOS: double (nullable = true)
#  |-- C16orf82: double (nullable = true)
#  |-- FUT4: double (nullable = true)
#  |-- ASB17: double (nullable = true)
#  |-- APPL1: double (nullable = true)
#  |-- C1QTNF1: double (nullable = true)
#  |-- SAA2: double (nullable = true)
#  |-- GLI4: double (nullable = true)
#  |-- PRRG1: double (nullable = true)
#  |-- CCDC92B: double (nullable = true)
#  |-- ARNTL: double (nullable = true)
#  |-- GALM: double (nullable = true)
#  |-- RPL34-AS1: double (nullable = true)
#  |-- RPN1: double (nullable = true)
#  |-- TULP3: double (nullable = true)
#  |-- GALNTL5: double (nullable = true)
#  |-- NCAM1: double (nullable = true)
#  |-- MIR5695: double (nullable = true)
#  |-- LAMA1: double (nullable = true)
#  |-- MIR548H5: double (nullable = true)
#  |-- ARIH2: double (nullable = true)
#  |-- LINC02525: double (nullable = true)
#  |-- SERPINA13P: double (nullable = true)
#  |-- STK17A: double (nullable = true)
#  |-- LINC01951: double (nullable = true)
#  |-- DHCR7: double (nullable = true)
#  |-- ADCY6: double (nullable = true)
#  |-- OR11H6: double (nullable = true)
#  |-- ENOSF1: double (nullable = true)
#  |-- TMED9: double (nullable = true)
#  |-- LINC01476: double (nullable = true)
#  |-- TRIOBP: double (nullable = true)
#  |-- CEMIP: double (nullable = true)
#  |-- THAP2: double (nullable = true)
#  |-- YY1AP1: double (nullable = true)
#  |-- IL21R: double (nullable = true)
#  |-- LOC102724058: double (nullable = true)
#  |-- SMARCC2: double (nullable = true)
#  |-- MIR4799: double (nullable = true)
#  |-- CALML3: double (nullable = true)
#  |-- OR8D1: double (nullable = true)
#  |-- ACAT2: double (nullable = true)
#  |-- LOC101928748: double (nullable = true)
#  |-- PHF3: double (nullable = true)
#  |-- C1orf137: double (nullable = true)
#  |-- LILRB2: double (nullable = true)
#  |-- LINC00640: double (nullable = true)
#  |-- SRPRB: double (nullable = true)
#  |-- DGCR5: double (nullable = true)
#  |-- PDXDC2P-NPIPB14P: double (nullable = true)
#  |-- CPA6: double (nullable = true)
#  |-- ABTB2: double (nullable = true)
#  |-- TOR1AIP1: double (nullable = true)
#  |-- NIFK: double (nullable = true)
#  |-- LOC100287015: double (nullable = true)
#  |-- ZNF350: double (nullable = true)
#  |-- DSCR10: double (nullable = true)
#  |-- PRSS35: double (nullable = true)
#  |-- EXOG: double (nullable = true)
#  |-- ZNF157: double (nullable = true)
#  |-- TCEAL5: double (nullable = true)
#  |-- PUF60: double (nullable = true)
#  |-- TBC1D19: double (nullable = true)
#  |-- EPGN: double (nullable = true)
#  |-- ZNF521: double (nullable = true)
#  |-- MIR7849: double (nullable = true)
#  |-- PBLD: double (nullable = true)
#  |-- CNPY1: double (nullable = true)
#  |-- KRTAP7-1: double (nullable = true)
#  |-- LINC01928: double (nullable = true)
#  |-- ZNF592: double (nullable = true)
#  |-- LINC00971: double (nullable = true)
#  |-- C1QL1: double (nullable = true)
#  |-- SLC7A8: double (nullable = true)
#  |-- NKX2-8: double (nullable = true)
#  |-- TMEM104: double (nullable = true)
#  |-- CA10: double (nullable = true)
#  |-- CCDC138: double (nullable = true)
#  |-- MIR4772: double (nullable = true)
#  |-- LOC100507205: double (nullable = true)
#  |-- MAP3K21: double (nullable = true)
#  |-- EDA: double (nullable = true)
#  |-- PGAM4: double (nullable = true)
#  |-- DCAF4L2: double (nullable = true)
#  |-- FFAR2: double (nullable = true)
#  |-- VPS53: double (nullable = true)
#  |-- GAGE1: double (nullable = true)
#  |-- WIPF2: double (nullable = true)
#  |-- HOXB9: double (nullable = true)
#  |-- TRMT1L: double (nullable = true)
#  |-- GABBR2: double (nullable = true)
#  |-- SLC9A9: double (nullable = true)
#  |-- NFIA: double (nullable = true)
#  |-- LPCAT1: double (nullable = true)
#  |-- LINC01467: double (nullable = true)
#  |-- NECAB2: double (nullable = true)
#  |-- LINC00997: double (nullable = true)
#  |-- ATOH1: double (nullable = true)
#  |-- BIRC7: double (nullable = true)
#  |-- GAL: double (nullable = true)
#  |-- CLIP4: double (nullable = true)
#  |-- LOC100630923: double (nullable = true)
#  |-- F13B: double (nullable = true)
#  |-- SUN3: double (nullable = true)
#  |-- ANO1: double (nullable = true)
#  |-- ST7L: double (nullable = true)
#  |-- MFSD4A: double (nullable = true)
#  |-- LINC01435: double (nullable = true)
#  |-- TBCD: double (nullable = true)
#  |-- ALG3: double (nullable = true)
#  |-- NOC2LP2: double (nullable = true)
#  |-- ELMOD1: double (nullable = true)
#  |-- PHLDB1: double (nullable = true)
#  |-- ANKRD20A12P: double (nullable = true)
#  |-- DCAF6: double (nullable = true)
#  |-- DPP6: double (nullable = true)
#  |-- GRIFIN: double (nullable = true)
#  |-- SLC43A2: double (nullable = true)
#  |-- PSMB2: double (nullable = true)
#  |-- LINC02178: double (nullable = true)
#  |-- LRRC6: double (nullable = true)
#  |-- LINC02346: double (nullable = true)
#  |-- ASH2L: double (nullable = true)
#  |-- C15orf54: double (nullable = true)
#  |-- PWRN3: double (nullable = true)
#  |-- HIGD1B: double (nullable = true)
#  |-- POLR2B: double (nullable = true)
#  |-- ZFP82: double (nullable = true)
#  |-- APOB: double (nullable = true)
#  |-- SOCS4: double (nullable = true)
#  |-- SLC39A9: double (nullable = true)
#  |-- LRRC1: double (nullable = true)
#  |-- B3GNT2: double (nullable = true)
#  |-- COPS7B: double (nullable = true)
#  |-- TACC1: double (nullable = true)
#  |-- WDR78: double (nullable = true)
#  |-- LOC101927880: double (nullable = true)
#  |-- NSDHL: double (nullable = true)
#  |-- MAP10: double (nullable = true)
#  |-- RUSC1: double (nullable = true)
#  |-- MAP1S: double (nullable = true)
#  |-- EFEMP1: double (nullable = true)
#  |-- LINC00375: double (nullable = true)
#  |-- PPP1R9A: double (nullable = true)
#  |-- USP44: double (nullable = true)
#  |-- WARS2-AS1: double (nullable = true)
#  |-- LINC01593: double (nullable = true)
#  |-- MIR658: double (nullable = true)
#  |-- ZNF562: double (nullable = true)
#  |-- SERPINB4: double (nullable = true)
#  |-- TCAM1P: double (nullable = true)
#  |-- TMEM68: double (nullable = true)
#  |-- GTDC1: double (nullable = true)
#  |-- CPA4: double (nullable = true)
#  |-- PEX26: double (nullable = true)
#  |-- FMN1: double (nullable = true)
#  |-- DDB2: double (nullable = true)
#  |-- HSFY1: double (nullable = true)
#  |-- KIF13B: double (nullable = true)
#  |-- CRB2: double (nullable = true)
#  |-- DTNBP1: double (nullable = true)
#  |-- MT1IP: double (nullable = true)
#  |-- LMO7: double (nullable = true)
#  |-- OR5M10: double (nullable = true)
#  |-- GAP43: double (nullable = true)
#  |-- PSKH2: double (nullable = true)
#  |-- SEL1L3: double (nullable = true)
#  |-- AOAH: double (nullable = true)
#  |-- ZFAND2A: double (nullable = true)
#  |-- PDLIM4: double (nullable = true)
#  |-- CDRT15P1: double (nullable = true)
#  |-- ITLN1: double (nullable = true)
#  |-- PFAS: double (nullable = true)
#  |-- LAG3: double (nullable = true)
#  |-- PGM1: double (nullable = true)
#  |-- KRT9: double (nullable = true)
#  |-- NLGN1: double (nullable = true)
#  |-- MIR892C: double (nullable = true)
#  |-- VEGFC: double (nullable = true)
#  |-- ESAM: double (nullable = true)
#  |-- AKR7A3: double (nullable = true)
#  |-- SFXN4: double (nullable = true)
#  |-- ELOA: double (nullable = true)
#  |-- UBE2I: double (nullable = true)
#  |-- LINC02037: double (nullable = true)
#  |-- C20orf194: double (nullable = true)
#  |-- COQ6: double (nullable = true)
#  |-- GPNMB: double (nullable = true)
#  |-- MIR455: double (nullable = true)
#  |-- HIST1H1D: double (nullable = true)
#  |-- LINC01256: double (nullable = true)
#  |-- TLR2: double (nullable = true)
#  |-- MBD2: double (nullable = true)
#  |-- OR10X1: double (nullable = true)
#  |-- LINC01700: double (nullable = true)
#  |-- XLOC_008559: double (nullable = true)
#  |-- PAGE2: double (nullable = true)
#  |-- CFB: double (nullable = true)
#  |-- IL32: double (nullable = true)
#  |-- RMDN2: double (nullable = true)
#  |-- GLB1L2: double (nullable = true)
#  |-- UPP1: double (nullable = true)
#  |-- FKBP15: double (nullable = true)
#  |-- TTC34: double (nullable = true)
#  |-- OR2AK2: double (nullable = true)
#  |-- CKS2: double (nullable = true)
#  |-- BCAS4: double (nullable = true)
#  |-- ZNF788P: double (nullable = true)
#  |-- EXO1: double (nullable = true)
#  |-- MED16: double (nullable = true)
#  |-- IGSF9B: double (nullable = true)
#  |-- LRRC73: double (nullable = true)
#  |-- LHFPL6: double (nullable = true)
#  |-- LHFPL4: double (nullable = true)
#  |-- OR2T6: double (nullable = true)
#  |-- CENPF: double (nullable = true)
#  |-- HSPA12A: double (nullable = true)
#  |-- SKP1P2: double (nullable = true)
#  |-- TSPAN8: double (nullable = true)
#  |-- LOC101927795: double (nullable = true)
#  |-- SRL: double (nullable = true)
#  |-- POLG: double (nullable = true)
#  |-- MRGPRG: double (nullable = true)
#  |-- INPP5K: double (nullable = true)
#  |-- DHODH: double (nullable = true)
#  |-- ACY1: double (nullable = true)
#  |-- STMP1: double (nullable = true)
#  |-- THBS4: double (nullable = true)
#  |-- ULK4P3: double (nullable = true)
#  |-- WDR61: double (nullable = true)
#  |-- SMAP2: double (nullable = true)
#  |-- NPHP3: double (nullable = true)
#  |-- CELSR3: double (nullable = true)
#  |-- UBR4: double (nullable = true)
#  |-- LOC101927446: double (nullable = true)
#  |-- UBQLN3: double (nullable = true)
#  |-- ZBED5: double (nullable = true)
#  |-- HELZ: double (nullable = true)
#  |-- SETD3: double (nullable = true)
#  |-- RBP3: double (nullable = true)
#  |-- LINC00473: double (nullable = true)
#  |-- FLT3LG: double (nullable = true)
#  |-- DDN: double (nullable = true)
#  |-- LINC02414: double (nullable = true)
#  |-- SLC25A29: double (nullable = true)
#  |-- NCOR2: double (nullable = true)
#  |-- DPF1: double (nullable = true)
#  |-- ZFP91: double (nullable = true)
#  |-- EFCAB14: double (nullable = true)
#  |-- RNMT: double (nullable = true)
#  |-- SAMD11: double (nullable = true)
#  |-- FAM47E-STBD1: double (nullable = true)
#  |-- ERLIN2: double (nullable = true)
#  |-- LOC407835: double (nullable = true)
#  |-- PREP: double (nullable = true)
#  |-- PLA2G4E: double (nullable = true)
#  |-- ETNK2: double (nullable = true)
#  |-- GRINA: double (nullable = true)
#  |-- PPP2R3C: double (nullable = true)
#  |-- UPP2: double (nullable = true)
#  |-- SNX8: double (nullable = true)
#  |-- UBE4A: double (nullable = true)
#  |-- TRY2P: double (nullable = true)
#  |-- OMP: double (nullable = true)
#  |-- ESPNP: double (nullable = true)
#  |-- HP1BP3: double (nullable = true)
#  |-- SNORA88: double (nullable = true)
#  |-- LIN28B: double (nullable = true)
#  |-- LOC101928924: double (nullable = true)
#  |-- EFTUD2: double (nullable = true)
#  |-- ANKRD20A4: double (nullable = true)
#  |-- VPS41: double (nullable = true)
#  |-- LOC105372653: double (nullable = true)
#  |-- SRRD: double (nullable = true)
#  |-- MIR3908: double (nullable = true)
#  |-- MIR8079: double (nullable = true)
#  |-- ZNF664: double (nullable = true)
#  |-- PKD1P1: double (nullable = true)
#  |-- PANX3: double (nullable = true)
#  |-- LINC02011: double (nullable = true)
#  |-- ABCA10: double (nullable = true)
#  |-- SLC20A1: double (nullable = true)
#  |-- TBX4: double (nullable = true)
#  |-- LGI3: double (nullable = true)
#  |-- ZNF782: double (nullable = true)
#  |-- LINC02234: double (nullable = true)
#  |-- AKR1D1: double (nullable = true)
#  |-- LOC100506990: double (nullable = true)
#  |-- PUS1: double (nullable = true)
#  |-- NIPA1: double (nullable = true)
#  |-- TCF19: double (nullable = true)
#  |-- CARD10: double (nullable = true)
#  |-- SUSD1: double (nullable = true)
#  |-- DCAF13: double (nullable = true)
#  |-- SLCO3A1: double (nullable = true)
#  |-- LINC02188: double (nullable = true)
#  |-- CCND2: double (nullable = true)
#  |-- MPND: double (nullable = true)
#  |-- LINC01152: double (nullable = true)
#  |-- WFDC8: double (nullable = true)
#  |-- MRPL38: double (nullable = true)
#  |-- PSPC1: double (nullable = true)
#  |-- LINC01699: double (nullable = true)
#  |-- LOC643339: double (nullable = true)
#  |-- SEMA6D: double (nullable = true)
#  |-- COL8A1: double (nullable = true)
#  |-- SLC16A1-AS1: double (nullable = true)
#  |-- RHOJ: double (nullable = true)
#  |-- GIMAP6: double (nullable = true)
#  |-- MIR2392: double (nullable = true)
#  |-- HSFX4: double (nullable = true)
#  |-- SYNJ2: double (nullable = true)
#  |-- PPP2R2B: double (nullable = true)
#  |-- CUL4B: double (nullable = true)
#  |-- SNCG: double (nullable = true)
#  |-- ACTG1: double (nullable = true)
#  |-- OR5B17: double (nullable = true)
#  |-- HDAC4: double (nullable = true)
#  |-- UBE2D4: double (nullable = true)
#  |-- LOC388282: double (nullable = true)
#  |-- MIR7158: double (nullable = true)
#  |-- NSMCE3: double (nullable = true)
#  |-- EGLN3: double (nullable = true)
#  |-- TRAPPC5: double (nullable = true)
#  |-- ARHGEF39: double (nullable = true)
#  |-- LINC01032: double (nullable = true)
#  |-- HINFP: double (nullable = true)
#  |-- H3_Y: double (nullable = true)
#  |-- MYEF2: double (nullable = true)
#  |-- CASC1: double (nullable = true)
#  |-- SRD5A3-AS1: double (nullable = true)
#  |-- TMEM183A: double (nullable = true)
#  |-- OTUD5: double (nullable = true)
#  |-- PRRC2C: double (nullable = true)
#  |-- MPZ: double (nullable = true)
#  |-- APOOL: double (nullable = true)
#  |-- PRSS36: double (nullable = true)
#  |-- VSX2: double (nullable = true)
#  |-- CBX1: double (nullable = true)
#  |-- PLS3-AS1: double (nullable = true)
#  |-- LOC102724849: double (nullable = true)
#  |-- ADGRB2: double (nullable = true)
#  |-- WDR63: double (nullable = true)
#  |-- RPL23AP7: double (nullable = true)
#  |-- TMEM56: double (nullable = true)
#  |-- C6orf201: double (nullable = true)
#  |-- LOC101928279: double (nullable = true)
#  |-- USP32: double (nullable = true)
#  |-- AK5: double (nullable = true)
#  |-- EPS8L2: double (nullable = true)
#  |-- ARHGAP30: double (nullable = true)
#  |-- GOLGA6A: double (nullable = true)
#  |-- LINC01829: double (nullable = true)
#  |-- PSMB8: double (nullable = true)
#  |-- EFCAB6-AS1: double (nullable = true)
#  |-- SCHIP1: double (nullable = true)
#  |-- MYLK-AS1: double (nullable = true)
#  |-- GET4: double (nullable = true)
#  |-- ZNF763: double (nullable = true)
#  |-- LINC02278: double (nullable = true)
#  |-- LINC01924: double (nullable = true)
#  |-- ABCB4: double (nullable = true)
#  |-- MIIP: double (nullable = true)
#  |-- WDR91: double (nullable = true)
#  |-- GSKIP: double (nullable = true)
#  |-- LINC01440: double (nullable = true)
#  |-- HLA-E: double (nullable = true)
#  |-- ING4: double (nullable = true)
#  |-- GAL3ST4: double (nullable = true)
#  |-- STAC2: double (nullable = true)
#  |-- ARHGEF38: double (nullable = true)
#  |-- LINC00844: double (nullable = true)
#  |-- ADIG: double (nullable = true)
#  |-- GGNBP2: double (nullable = true)
#  |-- ASB7: double (nullable = true)
#  |-- IL21-AS1: double (nullable = true)
#  |-- MADD: double (nullable = true)
#  |-- BCL2L10: double (nullable = true)
#  |-- CRLF3: double (nullable = true)
#  |-- FRG2KP: double (nullable = true)
#  |-- ZNF135: double (nullable = true)
#  |-- IMPG2: double (nullable = true)
#  |-- RSPO3: double (nullable = true)
#  |-- EDEM1: double (nullable = true)
#  |-- H2BFXP: double (nullable = true)
#  |-- TSSK4: double (nullable = true)
#  |-- LOC100129138: double (nullable = true)
#  |-- PIGQ: double (nullable = true)
#  |-- OR52A1: double (nullable = true)
#  |-- SLC15A3: double (nullable = true)
#  |-- P3H4: double (nullable = true)
#  |-- MICU3: double (nullable = true)
#  |-- PGM2L1: double (nullable = true)
#  |-- ARID3B: double (nullable = true)
#  |-- ZNF169: double (nullable = true)
#  |-- FAM9B: double (nullable = true)
#  |-- RFT1: double (nullable = true)
#  |-- LINC01480: double (nullable = true)
#  |-- MIR2114: double (nullable = true)
#  |-- TMCC1: double (nullable = true)
#  |-- RRP7A: double (nullable = true)
#  |-- MTFR1: double (nullable = true)
#  |-- MSI1: double (nullable = true)
#  |-- LINC02103: double (nullable = true)
#  |-- SHKBP1: double (nullable = true)
#  |-- KRTAP1-3: double (nullable = true)
#  |-- RLIM: double (nullable = true)
#  |-- SLC22A17: double (nullable = true)
#  |-- B3GAT1: double (nullable = true)
#  |-- MZT2A: double (nullable = true)
#  |-- NBPF1: double (nullable = true)
#  |-- LOC105616981: double (nullable = true)
#  |-- HIST1H4B: double (nullable = true)
#  |-- A2M-AS1: double (nullable = true)
#  |-- PEX13: double (nullable = true)
#  |-- ARG1: double (nullable = true)
#  |-- SRGAP1: double (nullable = true)
#  |-- HIST1H4H: double (nullable = true)
#  |-- OSTM1: double (nullable = true)
#  |-- CWC25: double (nullable = true)
#  |-- ZNF461: double (nullable = true)
#  |-- IFT57: double (nullable = true)
#  |-- GK: double (nullable = true)
#  |-- RASSF1: double (nullable = true)
#  |-- LOC101928295: double (nullable = true)
#  |-- LOC105373553: double (nullable = true)
#  |-- NBN: double (nullable = true)
#  |-- EHHADH: double (nullable = true)
#  |-- LINC02453: double (nullable = true)
#  |-- NCOA5: double (nullable = true)
#  |-- SIGLEC10: double (nullable = true)
#  |-- ZNF91: double (nullable = true)
#  |-- PRPF38A: double (nullable = true)
#  |-- NUDT14: double (nullable = true)
#  |-- CT45A1: double (nullable = true)
#  |-- ELOVL3: double (nullable = true)
#  |-- SMIM10: double (nullable = true)
#  |-- SEPHS2: double (nullable = true)
#  |-- FIG4: double (nullable = true)
#  |-- DUSP19: double (nullable = true)
#  |-- LINC00266-1: double (nullable = true)
#  |-- LINC00456: double (nullable = true)
#  |-- ONECUT1: double (nullable = true)
#  |-- YAF2: double (nullable = true)
#  |-- MYADML: double (nullable = true)
#  |-- BOD1L2: double (nullable = true)
#  |-- MRPS35: double (nullable = true)
#  |-- INTU: double (nullable = true)
#  |-- PBDC1: double (nullable = true)
#  |-- CST9L: double (nullable = true)
#  |-- DEFA6: double (nullable = true)
#  |-- TMPRSS12: double (nullable = true)
#  |-- TMEM101: double (nullable = true)
#  |-- MTNR1B: double (nullable = true)
#  |-- SRP68: double (nullable = true)
#  |-- LINC01493: double (nullable = true)
#  |-- TIGAR: double (nullable = true)
#  |-- CYSLTR2: double (nullable = true)
#  |-- KLK3: double (nullable = true)
#  |-- FGF17: double (nullable = true)
#  |-- ITGB3: double (nullable = true)
#  |-- NOTCH2NLR: double (nullable = true)
#  |-- PDK2: double (nullable = true)
#  |-- C4A: double (nullable = true)
#  |-- PRKRIP1: double (nullable = true)
#  |-- SGPP2: double (nullable = true)
#  |-- LINC01075: double (nullable = true)
#  |-- ZNF280A: double (nullable = true)
#  |-- NOB1: double (nullable = true)
#  |-- ANGPTL5: double (nullable = true)
#  |-- LOC105372440: double (nullable = true)
#  |-- HSFX3: double (nullable = true)
#  |-- H2BFS: double (nullable = true)
#  |-- AIF1L: double (nullable = true)
#  |-- ZNF286A: double (nullable = true)
#  |-- LINC00940: double (nullable = true)
#  |-- CTSE: double (nullable = true)
#  |-- CRISP3: double (nullable = true)
#  |-- RNASE11: double (nullable = true)
#  |-- C15orf39: double (nullable = true)
#  |-- AGPS: double (nullable = true)
#  |-- OR1C1: double (nullable = true)
#  |-- DPY19L2: double (nullable = true)
#  |-- GHSR: double (nullable = true)
#  |-- VPS13D: double (nullable = true)
#  |-- ARPC1B: double (nullable = true)
#  |-- HSD3B2: double (nullable = true)
#  |-- TUSC3: double (nullable = true)
#  |-- NKAIN4: double (nullable = true)
#  |-- KRTAP21-2: double (nullable = true)
#  |-- CADM3: double (nullable = true)
#  |-- CCNC: double (nullable = true)
#  |-- TRAPPC3L: double (nullable = true)
#  |-- LDLRAD4: double (nullable = true)
#  |-- LOC100134868: double (nullable = true)
#  |-- MIR7-2: double (nullable = true)
#  |-- LOC101927402: double (nullable = true)
#  |-- GLOD4: double (nullable = true)
#  |-- TMEM235: double (nullable = true)
#  |-- ARPC5: double (nullable = true)
#  |-- FARP1: double (nullable = true)
#  |-- PRPSAP1: double (nullable = true)
#  |-- LINC01586: double (nullable = true)
#  |-- KCTD1: double (nullable = true)
#  |-- ZNF32: double (nullable = true)
#  |-- LINC02217: double (nullable = true)
#  |-- PTPRH: double (nullable = true)
#  |-- LINC01074: double (nullable = true)
#  |-- CDRT1: double (nullable = true)
#  |-- TMEM17: double (nullable = true)
#  |-- LINC00968: double (nullable = true)
#  |-- MRPL50: double (nullable = true)
#  |-- TSPOAP1-AS1: double (nullable = true)
#  |-- SPATA41: double (nullable = true)
#  |-- MPV17L2: double (nullable = true)
#  |-- PRODH2: double (nullable = true)
#  |-- ZNF853: double (nullable = true)
#  |-- TXLNGY: double (nullable = true)
#  |-- FAM210A: double (nullable = true)
#  |-- SH3BP4: double (nullable = true)
#  |-- MUC4: double (nullable = true)
#  |-- MAP2K3: double (nullable = true)
#  |-- LINC02408: double (nullable = true)
#  |-- OR10J1: double (nullable = true)
#  |-- URI1: double (nullable = true)
#  |-- POC1B: double (nullable = true)
#  |-- PLEKHG2: double (nullable = true)
#  |-- OSBPL1A: double (nullable = true)
#  |-- LINC01882: double (nullable = true)
#  |-- FLJ37035: double (nullable = true)
#  |-- PIGX: double (nullable = true)
#  |-- LINC00426: double (nullable = true)
#  |-- RPP25L: double (nullable = true)
#  |-- ELK1: double (nullable = true)
#  |-- ZNF709: double (nullable = true)
#  |-- TXN2: double (nullable = true)
#  |-- KLHL2: double (nullable = true)
#  |-- ATP1B3: double (nullable = true)
#  |-- IL16: double (nullable = true)
#  |-- IDS: double (nullable = true)
#  |-- AIRE: double (nullable = true)
#  |-- LINC00477: double (nullable = true)
#  |-- CPA2: double (nullable = true)
#  |-- LOC102725021: double (nullable = true)
#  |-- LINC00184: double (nullable = true)
#  |-- COPS9: double (nullable = true)
#  |-- LOC101928093: double (nullable = true)
#  |-- LCORL: double (nullable = true)
#  |-- MTTP: double (nullable = true)
#  |-- IFT80: double (nullable = true)
#  |-- WDR70: double (nullable = true)
#  |-- CCDC17: double (nullable = true)
#  |-- WDSUB1: double (nullable = true)
#  |-- CNN2: double (nullable = true)
#  |-- YRDC: double (nullable = true)
#  |-- BMS1P21: double (nullable = true)
#  |-- LINC02343: double (nullable = true)
#  |-- UBOX5: double (nullable = true)
#  |-- VN1R2: double (nullable = true)
#  |-- ZBED3-AS1: double (nullable = true)
#  |-- GRSF1: double (nullable = true)
#  |-- THOC7: double (nullable = true)
#  |-- SCARB2: double (nullable = true)
#  |-- HLA-DMB: double (nullable = true)
#  |-- MAK: double (nullable = true)
#  |-- C12orf45: double (nullable = true)
#  |-- C9orf85: double (nullable = true)
#  |-- LOC107984974: double (nullable = true)
#  |-- ZNF236: double (nullable = true)
#  |-- LOC101929099: double (nullable = true)
#  |-- LOC105378127: double (nullable = true)
#  |-- ACTN1-AS1: double (nullable = true)
#  |-- DHRS4L2: double (nullable = true)
#  |-- BCAT1: double (nullable = true)
#  |-- MBL1P: double (nullable = true)
#  |-- DUSP23: double (nullable = true)
#  |-- SERPINH1: double (nullable = true)
#  |-- CYCS: double (nullable = true)
#  |-- DMXL2: double (nullable = true)
#  |-- WDR49: double (nullable = true)
#  |-- ZNF559: double (nullable = true)
#  |-- LINC01879: double (nullable = true)
#  |-- NEURL1B: double (nullable = true)
#  |-- HTR3D: double (nullable = true)
#  |-- MGAT4EP: double (nullable = true)
#  |-- SYCP2L: double (nullable = true)
#  |-- EVA1B: double (nullable = true)
#  |-- ST20-MTHFS: double (nullable = true)
#  |-- TNFRSF1A: double (nullable = true)
#  |-- ATP6V0A1: double (nullable = true)
#  |-- SCN4B: double (nullable = true)
#  |-- LINC00353: double (nullable = true)
#  |-- DRP2: double (nullable = true)
#  |-- RBPJL: double (nullable = true)
#  |-- TMEM216: double (nullable = true)
#  |-- CD1E: double (nullable = true)
#  |-- SERPINB3: double (nullable = true)
#  |-- WNK3: double (nullable = true)
#  |-- RFNG: double (nullable = true)
#  |-- LINC02085: double (nullable = true)
#  |-- TMED7-TICAM2: double (nullable = true)
#  |-- MATN3: double (nullable = true)
#  |-- WAC-AS1: double (nullable = true)
#  |-- LOC283177: double (nullable = true)
#  |-- FAM47E: double (nullable = true)
#  |-- CADPS2: double (nullable = true)
#  |-- ARNTL2-AS1: double (nullable = true)
#  |-- LINC00974: double (nullable = true)
#  |-- REXO4: double (nullable = true)
#  |-- LOC401557: double (nullable = true)
#  |-- TBCB: double (nullable = true)
#  |-- C10orf71: double (nullable = true)
#  |-- ZNF727: double (nullable = true)
#  |-- GALNT15: double (nullable = true)
#  |-- ELDR: double (nullable = true)
#  |-- ADRB2: double (nullable = true)
#  |-- PANCR: double (nullable = true)
#  |-- TAS2R4: double (nullable = true)
#  |-- XPR1: double (nullable = true)
#  |-- SH3RF1: double (nullable = true)
#  |-- LINC00582: double (nullable = true)
#  |-- LINC01574: double (nullable = true)
#  |-- TSBP1: double (nullable = true)
#  |-- FAM83A: double (nullable = true)
#  |-- LOC283214: double (nullable = true)
#  |-- IGSF10: double (nullable = true)
#  |-- TMEM171: double (nullable = true)
#  |-- NELFCD: double (nullable = true)
#  |-- RPS9: double (nullable = true)
#  |-- CCDC168: double (nullable = true)
#  |-- RBM18: double (nullable = true)
#  |-- CCZ1: double (nullable = true)
#  |-- TMEM200A: double (nullable = true)
#  |-- MRTFB: double (nullable = true)
#  |-- CRYBB2P1: double (nullable = true)
#  |-- DENND5B: double (nullable = true)
#  |-- CHAF1A: double (nullable = true)
#  |-- ZMYND15: double (nullable = true)
#  |-- GSPT2: double (nullable = true)
#  |-- CRIPT: double (nullable = true)
#  |-- PRR12: double (nullable = true)
#  |-- AURKC: double (nullable = true)
#  |-- PAM: double (nullable = true)
#  |-- ADD3: double (nullable = true)
#  |-- UBR3: double (nullable = true)
#  |-- NSG1: double (nullable = true)
#  |-- SLC2A11: double (nullable = true)
#  |-- PPM1H: double (nullable = true)
#  |-- BUB1B: double (nullable = true)
#  |-- OR7C1: double (nullable = true)
#  |-- CYP2A7: double (nullable = true)
#  |-- CEBPD: double (nullable = true)
#  |-- COPS4: double (nullable = true)
#  |-- CIZ1: double (nullable = true)
#  |-- NR1H3: double (nullable = true)
#  |-- LINC02329: double (nullable = true)
#  |-- SMG1: double (nullable = true)
#  |-- OR10V1: double (nullable = true)
#  |-- F5: double (nullable = true)
#  |-- POT1-AS1: double (nullable = true)
#  |-- ANKS1B: double (nullable = true)
#  |-- LINC02069: double (nullable = true)
#  |-- MPP3: double (nullable = true)
#  |-- KCNK9: double (nullable = true)
#  |-- PCDHGB7: double (nullable = true)
#  |-- FAM230I: double (nullable = true)
#  |-- TDRD1: double (nullable = true)
#  |-- TRIM22: double (nullable = true)
#  |-- DEFB131A: double (nullable = true)
#  |-- UQCRFS1: double (nullable = true)
#  |-- ESRRB: double (nullable = true)
#  |-- ANXA2P2: double (nullable = true)
#  |-- KRT16: double (nullable = true)
#  |-- SH3PXD2A: double (nullable = true)
#  |-- CER1: double (nullable = true)
#  |-- DPY19L4: double (nullable = true)
#  |-- METTL21A: double (nullable = true)
#  |-- CD276: double (nullable = true)
#  |-- NT5DC1: double (nullable = true)
#  |-- EIF4ENIF1: double (nullable = true)
#  |-- CDK1: double (nullable = true)
#  |-- LINC00519: double (nullable = true)
#  |-- EHBP1L1: double (nullable = true)
#  |-- NAA25: double (nullable = true)
#  |-- RAB11FIP3: double (nullable = true)
#  |-- LINC02509: double (nullable = true)
#  |-- TAF11: double (nullable = true)
#  |-- GARNL3: double (nullable = true)
#  |-- JMJD1C: double (nullable = true)
#  |-- KIF13A: double (nullable = true)
#  |-- LCK: double (nullable = true)
#  |-- KLKB1: double (nullable = true)
#  |-- SYDE1: double (nullable = true)
#  |-- GSK3B: double (nullable = true)
#  |-- SLC25A12: double (nullable = true)
#  |-- SLC25A46: double (nullable = true)
#  |-- CSNK2A2: double (nullable = true)
#  |-- HIST1H1T: double (nullable = true)
#  |-- BNIP1: double (nullable = true)
#  |-- MCL1: double (nullable = true)
#  |-- E4F1: double (nullable = true)
#  |-- CLPX: double (nullable = true)
#  |-- GATB: double (nullable = true)
#  |-- KREMEN2: double (nullable = true)
#  |-- OR5T2: double (nullable = true)
#  |-- GRK3: double (nullable = true)
#  |-- GTF3C2: double (nullable = true)
#  |-- SERF1B: double (nullable = true)
#  |-- WARS: double (nullable = true)
#  |-- HLA-C: double (nullable = true)
#  |-- OR2T2: double (nullable = true)
#  |-- PPFIBP1: double (nullable = true)
#  |-- ASGR1: double (nullable = true)
#  |-- ATP8B1: double (nullable = true)
#  |-- PAFAH2: double (nullable = true)
#  |-- SLC38A3: double (nullable = true)
#  |-- NUP93: double (nullable = true)
#  |-- MYSM1: double (nullable = true)
#  |-- CSTF1: double (nullable = true)
#  |-- RFLNA: double (nullable = true)
#  |-- LOC400682: double (nullable = true)
#  |-- LOC100129307: double (nullable = true)
#  |-- LINC02580: double (nullable = true)
#  |-- USP36: double (nullable = true)
#  |-- CCL15-CCL14: double (nullable = true)
#  |-- RD3: double (nullable = true)
#  |-- LINC01582: double (nullable = true)
#  |-- KATNAL2: double (nullable = true)
#  |-- AMFR: double (nullable = true)
#  |-- L3MBTL1: double (nullable = true)
#  |-- ISM2: double (nullable = true)
#  |-- PHF12: double (nullable = true)
#  |-- CLEC14A: double (nullable = true)
#  |-- CACNA1G: double (nullable = true)
#  |-- MELTF: double (nullable = true)
#  |-- IL12B: double (nullable = true)
#  |-- SMYD3: double (nullable = true)
#  |-- ABRA: double (nullable = true)
#  |-- CLSTN1: double (nullable = true)
#  |-- SCYL2: double (nullable = true)
#  |-- SPATA31A5: double (nullable = true)
#  |-- MAPKAPK2: double (nullable = true)
#  |-- VGLL1: double (nullable = true)
#  |-- MYD88: double (nullable = true)
#  |-- GMNN: double (nullable = true)
#  |-- ALKAL1: double (nullable = true)
#  |-- LOC641746: double (nullable = true)
#  |-- ASPG: double (nullable = true)
#  |-- GOLGA7: double (nullable = true)
#  |-- CCDC184: double (nullable = true)
#  |-- TIFAB: double (nullable = true)
#  |-- ZNF552: double (nullable = true)
#  |-- TSHZ2: double (nullable = true)
#  |-- FAM238B: double (nullable = true)
#  |-- LOC105374428: double (nullable = true)
#  |-- PHKA1: double (nullable = true)
#  |-- LOC101929352: double (nullable = true)
#  |-- SLC25A23: double (nullable = true)
#  |-- CBX4: double (nullable = true)
#  |-- BLOC1S6: double (nullable = true)
#  |-- ZNF524: double (nullable = true)
#  |-- RBFOX1: double (nullable = true)
#  |-- GJD2: double (nullable = true)
#  |-- STRADB: double (nullable = true)
#  |-- PRKAG3: double (nullable = true)
#  |-- LINC01981: double (nullable = true)
#  |-- TRIM33: double (nullable = true)
#  |-- CBLN3: double (nullable = true)
#  |-- ZDHHC22: double (nullable = true)
#  |-- TBCEL: double (nullable = true)
#  |-- MIR184: double (nullable = true)
#  |-- OR5I1: double (nullable = true)
#  |-- ZNF804A: double (nullable = true)
#  |-- THG1L: double (nullable = true)
#  |-- GRM1: double (nullable = true)
#  |-- MIR4487: double (nullable = true)
#  |-- ZFYVE1: double (nullable = true)
#  |-- MFRP: double (nullable = true)
#  |-- NAV2: double (nullable = true)
#  |-- MIR4445: double (nullable = true)
#  |-- LINC01246: double (nullable = true)
#  |-- GNAQ: double (nullable = true)
#  |-- RGL4: double (nullable = true)
#  |-- HMGB2: double (nullable = true)
#  |-- TUSC1: double (nullable = true)
#  |-- GLS: double (nullable = true)
#  |-- CS: double (nullable = true)
#  |-- CCR3: double (nullable = true)
#  |-- ZNF98: double (nullable = true)
#  |-- PEX1: double (nullable = true)
#  |-- TEN1-CDK3: double (nullable = true)
#  |-- LOC101929415: double (nullable = true)
#  |-- LINC01043: double (nullable = true)
#  |-- MSTN: double (nullable = true)
#  |-- KCNN4: double (nullable = true)
#  |-- TNS2: double (nullable = true)
#  |-- LINC01913: double (nullable = true)
#  |-- DNAH1: double (nullable = true)
#  |-- C7orf31: double (nullable = true)
#  |-- KATNA1: double (nullable = true)
#  |-- LINC00840: double (nullable = true)
#  |-- LINC00544: double (nullable = true)
#  |-- CATSPERD: double (nullable = true)
#  |-- SLC5A9: double (nullable = true)
#  |-- PLA2G1B: double (nullable = true)
#  |-- FRAT1: double (nullable = true)
#  |-- SLCO4A1: double (nullable = true)
#  |-- KLF17: double (nullable = true)
#  |-- DOK6: double (nullable = true)
#  |-- GAGE4: double (nullable = true)
#  |-- CAPN11: double (nullable = true)
#  |-- PALMD: double (nullable = true)
#  |-- SRMS: double (nullable = true)
#  |-- FADS3: double (nullable = true)
#  |-- G6PC3: double (nullable = true)
#  |-- LINC01568: double (nullable = true)
#  |-- LINC01904: double (nullable = true)
#  |-- FAM234B: double (nullable = true)
#  |-- ZC3H11A: double (nullable = true)
#  |-- LOC100130476: double (nullable = true)
#  |-- ATXN3: double (nullable = true)
#  |-- HCN2: double (nullable = true)
#  |-- KERA: double (nullable = true)
#  |-- BTF3P11: double (nullable = true)
#  |-- LINC00868: double (nullable = true)
#  |-- RPL11: double (nullable = true)
#  |-- LINC00904: double (nullable = true)
#  |-- SP100: double (nullable = true)
#  |-- LOC643327: double (nullable = true)
#  |-- LOC101929140: double (nullable = true)
#  |-- ST18: double (nullable = true)
#  |-- SPRR1A: double (nullable = true)
#  |-- CDKN2B-AS1: double (nullable = true)
#  |-- PTRHD1: double (nullable = true)
#  |-- CRX: double (nullable = true)
#  |-- ENTPD5: double (nullable = true)
#  |-- PANX1: double (nullable = true)
#  |-- LINC01315: double (nullable = true)
#  |-- PTGES3L-AARSD1: double (nullable = true)
#  |-- PDC: double (nullable = true)
#  |-- C1orf112: double (nullable = true)
#  |-- TMEM54: double (nullable = true)
#  |-- MVD: double (nullable = true)
#  |-- OR7G1: double (nullable = true)
#  |-- TBC1D2: double (nullable = true)
#  |-- SMKR1: double (nullable = true)
#  |-- LINC02159: double (nullable = true)
#  |-- STX11: double (nullable = true)
#  |-- LUC7L2: double (nullable = true)
#  |-- SLITRK4: double (nullable = true)
#  |-- NLGN4X: double (nullable = true)
#  |-- AQP9: double (nullable = true)
#  |-- KIT: double (nullable = true)
#  |-- RPS14: double (nullable = true)
#  |-- FAR1: double (nullable = true)
#  |-- ZCCHC4: double (nullable = true)
#  |-- MIR4526: double (nullable = true)
#  |-- NUAK2: double (nullable = true)
#  |-- LINC02407: double (nullable = true)
#  |-- ITCH: double (nullable = true)
#  |-- MSX2: double (nullable = true)
#  |-- SLC39A11: double (nullable = true)
#  |-- LINC01287: double (nullable = true)
#  |-- DNAJB9: double (nullable = true)
#  |-- MIR4453HG: double (nullable = true)
#  |-- METTL14-DT: double (nullable = true)
#  |-- CZ1P-ASNS: double (nullable = true)
#  |-- KRT36: double (nullable = true)
#  |-- ADAM20P1: double (nullable = true)
#  |-- TRIM34: double (nullable = true)
#  |-- GNAT3: double (nullable = true)
#  |-- LINC02005: double (nullable = true)
#  |-- LINC02482: double (nullable = true)
#  |-- TMEM196: double (nullable = true)
#  |-- MARK4: double (nullable = true)
#  |-- FSIP2-AS2: double (nullable = true)
#  |-- CHCHD2: double (nullable = true)
#  |-- PHF1: double (nullable = true)
#  |-- LINC01053: double (nullable = true)
#  |-- STK24: double (nullable = true)
#  |-- TTLL6: double (nullable = true)
#  |-- CR2: double (nullable = true)
#  |-- OR4D9: double (nullable = true)
#  |-- FAM90A27P: double (nullable = true)
#  |-- LOC389705: double (nullable = true)
#  |-- STRAP: double (nullable = true)
#  |-- ERFE: double (nullable = true)
#  |-- CCDC59: double (nullable = true)
#  |-- SLC9A6: double (nullable = true)
#  |-- THRSP: double (nullable = true)
#  |-- NXPE1: double (nullable = true)
#  |-- MKRN3: double (nullable = true)
#  |-- LINC02611: double (nullable = true)
#  |-- FYCO1: double (nullable = true)
#  |-- PKN1: double (nullable = true)
#  |-- TCF7L1: double (nullable = true)
#  |-- ZNF722P: double (nullable = true)
#  |-- ZNF660: double (nullable = true)
#  |-- ARL14EP: double (nullable = true)
#  |-- VPS4A: double (nullable = true)
#  |-- BEND3: double (nullable = true)
#  |-- SIPA1L3: double (nullable = true)
#  |-- MIR4475: double (nullable = true)
#  |-- PLEKHB2: double (nullable = true)
#  |-- RGPD6: double (nullable = true)
#  |-- FOXG1-AS1: double (nullable = true)
#  |-- LINC02004: double (nullable = true)
#  |-- LINC02042: double (nullable = true)
#  |-- AQP12B: double (nullable = true)
#  |-- CASTOR3: double (nullable = true)
#  |-- LOC101929210: double (nullable = true)
#  |-- NBEAP1: double (nullable = true)
#  |-- ZSWIM4: double (nullable = true)
#  |-- NKIRAS1: double (nullable = true)
#  |-- FAM114A2: double (nullable = true)
#  |-- GPR149: double (nullable = true)
#  |-- OSCP1: double (nullable = true)
#  |-- COMMD4: double (nullable = true)
#  |-- IRGQ: double (nullable = true)
#  |-- NRG4: double (nullable = true)
#  |-- CYB5A: double (nullable = true)
#  |-- HLCS: double (nullable = true)
#  |-- MRPL10: double (nullable = true)
#  |-- AEBP1: double (nullable = true)
#  |-- FANCC: double (nullable = true)
#  |-- MAPK14: double (nullable = true)
#  |-- AGBL5: double (nullable = true)
#  |-- PRB4: double (nullable = true)
#  |-- SFR1: double (nullable = true)
#  |-- ZNF165: double (nullable = true)
#  |-- STK26: double (nullable = true)
#  |-- AFDN-DT: double (nullable = true)
#  |-- HGS: double (nullable = true)
#  |-- FNTB: double (nullable = true)
#  |-- VPS9D1: double (nullable = true)
#  |-- SLC6A13: double (nullable = true)
#  |-- PTCRA: double (nullable = true)
#  |-- ZNF420: double (nullable = true)
#  |-- PWWP3A: double (nullable = true)
#  |-- MIR222: double (nullable = true)
#  |-- LOC100506083: double (nullable = true)
#  |-- MIR548AP: double (nullable = true)
#  |-- SMIM17: double (nullable = true)
#  |-- ARMC12: double (nullable = true)
#  |-- EIF3J: double (nullable = true)
#  |-- NEUROD1: double (nullable = true)
#  |-- FLJ40288: double (nullable = true)
#  |-- FAM238C: double (nullable = true)
#  |-- RUFY4: double (nullable = true)
#  |-- RNASE3: double (nullable = true)
#  |-- SIM1: double (nullable = true)
#  |-- IDH1-AS1: double (nullable = true)
#  |-- FXN: double (nullable = true)
#  |-- LINC00424: double (nullable = true)
#  |-- RAD54L: double (nullable = true)
#  |-- VWA1: double (nullable = true)
#  |-- RBPJ: double (nullable = true)
#  |-- YTHDC2: double (nullable = true)
#  |-- NR2F6: double (nullable = true)
#  |-- EIF4G1: double (nullable = true)
#  |-- BMI1: double (nullable = true)
#  |-- CAND2: double (nullable = true)
#  |-- PLA2G2F: double (nullable = true)
#  |-- GUCY2GP: double (nullable = true)
#  |-- PTPN1: double (nullable = true)
#  |-- FPGT-TNNI3K: double (nullable = true)
#  |-- SOCS2: double (nullable = true)
#  |-- SLC45A2: double (nullable = true)
#  |-- SNTN: double (nullable = true)
#  |-- BAALC: double (nullable = true)
#  |-- ARAP2: double (nullable = true)
#  |-- PPP1R1B: double (nullable = true)
#  |-- ZDBF2: double (nullable = true)
#  |-- GCA: double (nullable = true)
#  |-- ZAR1: double (nullable = true)
#  |-- PLEKHG4B: double (nullable = true)
#  |-- OS9: double (nullable = true)
#  |-- KCNJ4: double (nullable = true)
#  |-- MFN2: double (nullable = true)
#  |-- ATP6V1B2: double (nullable = true)
#  |-- FNTA: double (nullable = true)
#  |-- HCST: double (nullable = true)
#  |-- NIT2: double (nullable = true)
#  |-- CCDC113: double (nullable = true)
#  |-- STRCP1: double (nullable = true)
#  |-- SYT7: double (nullable = true)
#  |-- INIP: double (nullable = true)
#  |-- LSM7: double (nullable = true)
#  |-- DEFB4A: double (nullable = true)
#  |-- HCCS: double (nullable = true)
#  |-- LINC02174: double (nullable = true)
#  |-- LINC01018: double (nullable = true)
#  |-- SNORD74B: double (nullable = true)
#  |-- GBA: double (nullable = true)
#  |-- LINC02214: double (nullable = true)
#  |-- SPINDOC: double (nullable = true)
#  |-- RNASET2: double (nullable = true)
#  |-- CFAP43: double (nullable = true)
#  |-- WDFY1: double (nullable = true)
#  |-- PHACTR4: double (nullable = true)
#  |-- APTX: double (nullable = true)
#  |-- PPP3CB: double (nullable = true)
#  |-- RNF168: double (nullable = true)
#  |-- MLX: double (nullable = true)
#  |-- UBB: double (nullable = true)
#  |-- OSR1: double (nullable = true)
#  |-- SRP72: double (nullable = true)
#  |-- KRTAP13-4: double (nullable = true)
#  |-- MIR3169: double (nullable = true)
#  |-- PNP: double (nullable = true)
#  |-- EMP1: double (nullable = true)
#  |-- COMMD8: double (nullable = true)
#  |-- DNAJC6: double (nullable = true)
#  |-- TIGIT: double (nullable = true)
#  |-- DPH5: double (nullable = true)
#  |-- CAVIN3: double (nullable = true)
#  |-- C2CD4B: double (nullable = true)
#  |-- FOCAD: double (nullable = true)
#  |-- NNT: double (nullable = true)
#  |-- CHD9: double (nullable = true)
#  |-- DPP3: double (nullable = true)
#  |-- ATXN7: double (nullable = true)
#  |-- TXK: double (nullable = true)
#  |-- LINC01995: double (nullable = true)
#  |-- GUSBP11: double (nullable = true)
#  |-- ABCB8: double (nullable = true)
#  |-- NECTIN1: double (nullable = true)
#  |-- DOK5: double (nullable = true)
#  |-- HMGA1P7: double (nullable = true)
#  |-- ORAI1: double (nullable = true)
#  |-- ST3GAL6-AS1: double (nullable = true)
#  |-- KLF15: double (nullable = true)
#  |-- CST11: double (nullable = true)
#  |-- SLED1: double (nullable = true)
#  |-- SPOCD1: double (nullable = true)
#  |-- FGFR3: double (nullable = true)
#  |-- SF3B4: double (nullable = true)
#  |-- ACO2: double (nullable = true)
#  |-- GGT5: double (nullable = true)
#  |-- FGFR2: double (nullable = true)
#  |-- APOM: double (nullable = true)
#  |-- CARNMT1: double (nullable = true)
#  |-- LARS: double (nullable = true)
#  |-- ZNF644: double (nullable = true)
#  |-- BCORP1: double (nullable = true)
#  |-- HACD2: double (nullable = true)
#  |-- RPTOR: double (nullable = true)
#  |-- AATK: double (nullable = true)
#  |-- SLC25A44: double (nullable = true)
#  |-- TPM2: double (nullable = true)
#  |-- XRCC1: double (nullable = true)
#  |-- LRRC37A5P: double (nullable = true)
#  |-- PRKG2: double (nullable = true)
#  |-- NMNAT2: double (nullable = true)
#  |-- ARHGEF11: double (nullable = true)
#  |-- PIBF1: double (nullable = true)
#  |-- CLEC2L: double (nullable = true)
#  |-- CDCA7: double (nullable = true)
#  |-- ZNF503-AS2: double (nullable = true)
#  |-- PELO: double (nullable = true)
#  |-- CUZD1: double (nullable = true)
#  |-- HMG20A: double (nullable = true)
#  |-- CLIP2: double (nullable = true)
#  |-- LOC101927691: double (nullable = true)
#  |-- DESI2: double (nullable = true)
#  |-- PDCL: double (nullable = true)
#  |-- STIM1: double (nullable = true)
#  |-- DDX18: double (nullable = true)
#  |-- BMS1: double (nullable = true)
#  |-- LCE3D: double (nullable = true)
#  |-- LYRM4: double (nullable = true)
#  |-- LRRIQ4: double (nullable = true)
#  |-- TICRR: double (nullable = true)
#  |-- LINC00487: double (nullable = true)
#  |-- HELT: double (nullable = true)
#  |-- DUSP8: double (nullable = true)
#  |-- HIPK3: double (nullable = true)
#  |-- EFCAB9: double (nullable = true)
#  |-- TRAPPC13: double (nullable = true)
#  |-- CNTLN: double (nullable = true)
#  |-- CDHR3: double (nullable = true)
#  |-- MYCT1: double (nullable = true)
#  |-- NLRC5: double (nullable = true)
#  |-- GBAP1: double (nullable = true)
#  |-- PCDHGA2: double (nullable = true)
#  |-- CLRN2: double (nullable = true)
#  |-- DENND3: double (nullable = true)
#  |-- RASA4B: double (nullable = true)
#  |-- MRM2: double (nullable = true)
#  |-- CAPN5: double (nullable = true)
#  |-- MGAT4C: double (nullable = true)
#  |-- IFIT5: double (nullable = true)
#  |-- PIP5KL1: double (nullable = true)
#  |-- C5orf47: double (nullable = true)
#  |-- DBX2: double (nullable = true)
#  |-- ZNF658: double (nullable = true)
#  |-- ECI1: double (nullable = true)
#  |-- FSIP2: double (nullable = true)
#  |-- DICER1: double (nullable = true)
#  |-- SLC39A2: double (nullable = true)
#  |-- WFIKKN2: double (nullable = true)
#  |-- PLCH2: double (nullable = true)
#  |-- SPINK9: double (nullable = true)
#  |-- SEMG1: double (nullable = true)
#  |-- LINC00864: double (nullable = true)
#  |-- MOXD1: double (nullable = true)
#  |-- SMIM13: double (nullable = true)
#  |-- RGPD1: double (nullable = true)
#  |-- LOC100129636: double (nullable = true)
#  |-- SPECC1: double (nullable = true)
#  |-- BANK1: double (nullable = true)
#  |-- B4GALNT1: double (nullable = true)
#  |-- ANKMY2: double (nullable = true)
#  |-- ATPAF2: double (nullable = true)
#  |-- TRIQK: double (nullable = true)
#  |-- EI24: double (nullable = true)
#  |-- NPEPPS: double (nullable = true)
#  |-- CENPQ: double (nullable = true)
#  |-- KRT13: double (nullable = true)
#  |-- LGR6: double (nullable = true)
#  |-- PCBD2: double (nullable = true)
#  |-- CNPY2: double (nullable = true)
#  |-- SLFNL1-AS1: double (nullable = true)
#  |-- LOC101929431: double (nullable = true)
#  |-- CLIP1: double (nullable = true)
#  |-- MRGBP: double (nullable = true)
#  |-- C1QL2: double (nullable = true)
#  |-- CAV2: double (nullable = true)
#  |-- GGT1: double (nullable = true)
#  |-- SRSF5: double (nullable = true)
#  |-- AMACR: double (nullable = true)
#  |-- KRTAP3-1: double (nullable = true)
#  |-- GAB2: double (nullable = true)
#  |-- ARFGEF3: double (nullable = true)
#  |-- EHD1: double (nullable = true)
# ...
#  |-- LOC101929089: double (nullable = true)
#  |-- GJA1: double (nullable = true)
#  |-- FCHO2: double (nullable = true)
#  |-- HIST1H3J: double (nullable = true)
#  |-- ZNF432: double (nullable = true)
#  |-- MGC27345: double (nullable = true)
#  |-- RALGAPA1: double (nullable = true)
#  |-- TM4SF19-AS1: double (nullable = true)
#  |-- MRPS22: double (nullable = true)
#  |-- TMEM232: double (nullable = true)
#  |-- EIF4E3: double (nullable = true)
#  |-- MMP7: double (nullable = true)
#  |-- POLR1A: double (nullable = true)
#  |-- PCCB: double (nullable = true)
#  |-- LINC00114: double (nullable = true)
#  |-- SNX19: double (nullable = true)
#  |-- DHX34: double (nullable = true)
#  |-- MTLN: double (nullable = true)
#  |-- TGFB2: double (nullable = true)
#  |-- LINP1: double (nullable = true)
#  |-- DMAC1: double (nullable = true)
#  |-- MIR8054: double (nullable = true)
#  |-- C2CD2: double (nullable = true)
#  |-- FETUB: double (nullable = true)
#  |-- IFNA1: double (nullable = true)
#  |-- SLC51A: double (nullable = true)
#  |-- FAM76B: double (nullable = true)
#  |-- NOD1: double (nullable = true)
#  |-- DPH1: double (nullable = true)
#  |-- UBR1: double (nullable = true)
#  |-- LINC00619: double (nullable = true)
#  |-- NAT8B: double (nullable = true)
#  |-- TRMT5: double (nullable = true)
#  |-- ATP6V0A4: double (nullable = true)
#  |-- MARCH3: double (nullable = true)
#  |-- IFT88: double (nullable = true)
#  |-- INHBA: double (nullable = true)
#  |-- NICN1: double (nullable = true)
#  |-- PON3: double (nullable = true)
#  |-- TNFSF12: double (nullable = true)
#  |-- BMP3: double (nullable = true)
#  |-- RHD: double (nullable = true)
#  |-- MED22: double (nullable = true)
#  |-- GGACT: double (nullable = true)
#  |-- RABGGTB: double (nullable = true)
#  |-- CLCN3: double (nullable = true)
#  |-- SLC35F3: double (nullable = true)
#  |-- NSUN5P2: double (nullable = true)
#  |-- PLAGL1: double (nullable = true)
#  |-- OR5T3: double (nullable = true)
#  |-- DOCK9: double (nullable = true)
#  |-- SLC5A4-AS1: double (nullable = true)
#  |-- CHTOP: double (nullable = true)
#  |-- SYT10: double (nullable = true)
#  |-- LRRC49: double (nullable = true)
#  |-- APOE: double (nullable = true)
#  |-- ATG7: double (nullable = true)
#  |-- PTCH2: double (nullable = true)
#  |-- OR7C2: double (nullable = true)
#  |-- CACNB4: double (nullable = true)
#  |-- RETSAT: double (nullable = true)
#  |-- OR6C65: double (nullable = true)
#  |-- TCF25: double (nullable = true)
#  |-- PAPPA: double (nullable = true)
#  |-- DNAJC21: double (nullable = true)
#  |-- TNKS1BP1: double (nullable = true)
#  |-- OR10G8: double (nullable = true)
#  |-- LINC01581: double (nullable = true)
#  |-- LOC105376671: double (nullable = true)
#  |-- CHMP1B2P: double (nullable = true)
#  |-- MIR650: double (nullable = true)
#  |-- IGFBP7-AS1: double (nullable = true)
#  |-- ERVV-2: double (nullable = true)
#  |-- SPATA31D4: double (nullable = true)
#  |-- RBMXL2: double (nullable = true)
#  |-- F8A1: double (nullable = true)
#  |-- LDLR: double (nullable = true)
#  |-- NACC1: double (nullable = true)
#  |-- LINC01098: double (nullable = true)
#  |-- BROX: double (nullable = true)
#  |-- C5orf67: double (nullable = true)
#  |-- NOL11: double (nullable = true)
#  |-- IFNK: double (nullable = true)
#  |-- FXR2: double (nullable = true)
#  |-- RASSF6: double (nullable = true)
#  |-- PHC2: double (nullable = true)
#  |-- NUCB2: double (nullable = true)
#  |-- LINC02255: double (nullable = true)
#  |-- CSF3: double (nullable = true)
#  |-- SMCO1: double (nullable = true)
#  |-- ZNFX1: double (nullable = true)
#  |-- LINC02092: double (nullable = true)
#  |-- LINC01744: double (nullable = true)
#  |-- ZNF589: double (nullable = true)
#  |-- LOC644669: double (nullable = true)
#  |-- CA4: double (nullable = true)
#  |-- MOGAT1: double (nullable = true)
#  |-- GFM1: double (nullable = true)
#  |-- LOC105369212: double (nullable = true)
#  |-- SOX13: double (nullable = true)
#  |-- ITGBL1: double (nullable = true)
#  |-- EFCAB6: double (nullable = true)
#  |-- B4GALT5: double (nullable = true)
#  |-- RTN2: double (nullable = true)
#  |-- MLH3: double (nullable = true)
#  |-- ITPK1: double (nullable = true)
#  |-- ZIK1: double (nullable = true)
#  |-- HOTAIR: double (nullable = true)
#  |-- ARL4A: double (nullable = true)
#  |-- TSG1: double (nullable = true)
#  |-- SNAP91: double (nullable = true)
#  |-- MBD6: double (nullable = true)
#  |-- CDK20: double (nullable = true)
#  |-- SLC33A1: double (nullable = true)
#  |-- LINC01135: double (nullable = true)
#  |-- TRIM50: double (nullable = true)
#  |-- ERRFI1: double (nullable = true)
#  |-- C14orf180: double (nullable = true)
#  |-- KAZALD1: double (nullable = true)
#  |-- STXBP3: double (nullable = true)
#  |-- LINC01136: double (nullable = true)
#  |-- PFDN2: double (nullable = true)
#  |-- LINC02050: double (nullable = true)
#  |-- CHMP5: double (nullable = true)
#  |-- NIPBL-DT: double (nullable = true)
#  |-- OR1J2: double (nullable = true)
#  |-- PSMC5: double (nullable = true)
#  |-- ARL5B: double (nullable = true)
#  |-- GNB3: double (nullable = true)
#  |-- DCAF7: double (nullable = true)
#  |-- RNF10: double (nullable = true)
#  |-- SLC25A38: double (nullable = true)
#  |-- SHLD1: double (nullable = true)
#  |-- EMC9: double (nullable = true)
#  |-- PTTG1: double (nullable = true)
#  |-- OXT: double (nullable = true)
#  |-- SERPINB8: double (nullable = true)
#  |-- GPN1: double (nullable = true)
#  |-- STX16-NPEPL1: double (nullable = true)
#  |-- CFP: double (nullable = true)
#  |-- CD8B: double (nullable = true)
#  |-- NRXN3: double (nullable = true)
#  |-- ARSF: double (nullable = true)
#  |-- SLC12A6: double (nullable = true)
#  |-- LOC729737: double (nullable = true)
#  |-- TEKT3: double (nullable = true)
#  |-- ZNF185: double (nullable = true)
#  |-- VWA3B: double (nullable = true)
#  |-- PAX6: double (nullable = true)
#  |-- LRRC37A3: double (nullable = true)
#  |-- ERCC3: double (nullable = true)
#  |-- ATP9B: double (nullable = true)
#  |-- FAHD2B: double (nullable = true)
#  |-- LINC02205: double (nullable = true)
#  |-- SCAT1: double (nullable = true)
#  |-- VASH1-AS1: double (nullable = true)
#  |-- COMMD1: double (nullable = true)
#  |-- MIR6078: double (nullable = true)
#  |-- CDT1: double (nullable = true)
#  |-- LINC02428: double (nullable = true)
#  |-- FRS2: double (nullable = true)
#  |-- NRG1: double (nullable = true)
#  |-- TMEM121: double (nullable = true)
#  |-- SPAAR: double (nullable = true)
#  |-- C12orf73: double (nullable = true)
#  |-- FAM200A: double (nullable = true)
#  |-- SGCG: double (nullable = true)
#  |-- ARHGEF26: double (nullable = true)
#  |-- MYOG: double (nullable = true)
#  |-- MIR2052: double (nullable = true)
#  |-- PPP1R2P2: double (nullable = true)
#  |-- WHAMMP1: double (nullable = true)
#  |-- PMVK: double (nullable = true)
#  |-- MOSPD2: double (nullable = true)
#  |-- LINC01337: double (nullable = true)
#  |-- FCER1A: double (nullable = true)
#  |-- ZNF428: double (nullable = true)
#  |-- RAP1GDS1: double (nullable = true)
#  |-- FUT8: double (nullable = true)
#  |-- MGAM: double (nullable = true)
#  |-- HSPB2-C11orf52: double (nullable = true)
#  |-- SOD1: double (nullable = true)
#  |-- NID2: double (nullable = true)
#  |-- SRP54-AS1: double (nullable = true)
#  |-- CYTH3: double (nullable = true)
#  |-- GLIS3: double (nullable = true)
#  |-- CLEC7A: double (nullable = true)
#  |-- PPP1R32: double (nullable = true)
#  |-- KCNC4: double (nullable = true)
#  |-- FAM167A-AS1: double (nullable = true)
#  |-- GVINP1: double (nullable = true)
#  |-- FAM241A: double (nullable = true)
#  |-- GAB1: double (nullable = true)
#  |-- CACNA2D3: double (nullable = true)
#  |-- CEP57L1: double (nullable = true)
#  |-- LSG1: double (nullable = true)
#  |-- IL20: double (nullable = true)
#  |-- SKIDA1: double (nullable = true)
#  |-- EFNA4: double (nullable = true)
#  |-- PPP2R3A: double (nullable = true)
#  |-- TNIP1: double (nullable = true)
#  |-- GUCY2C: double (nullable = true)
#  |-- PIP4K2B: double (nullable = true)
#  |-- CLK4: double (nullable = true)
#  |-- RALGPS1: double (nullable = true)
#  |-- NFATC2: double (nullable = true)
#  |-- LOC102723427: double (nullable = true)
#  |-- KNCN: double (nullable = true)
#  |-- NXF2: double (nullable = true)
#  |-- TMEM178A: double (nullable = true)
#  |-- SEC23B: double (nullable = true)
#  |-- TRIML1: double (nullable = true)
#  |-- TCF21: double (nullable = true)
#  |-- BSN: double (nullable = true)
#  |-- KLHDC2: double (nullable = true)
#  |-- LCE3C: double (nullable = true)
#  |-- C5orf66: double (nullable = true)
#  |-- ESPNL: double (nullable = true)
#  |-- NEK6: double (nullable = true)
#  |-- OR2W3: double (nullable = true)
#  |-- ABLIM1: double (nullable = true)
#  |-- TCL1A: double (nullable = true)
#  |-- BCORL1: double (nullable = true)
#  |-- NTNG1: double (nullable = true)
#  |-- SNRPB2: double (nullable = true)
#  |-- ATP4A: double (nullable = true)
#  |-- LEPROT: double (nullable = true)
#  |-- NNMT: double (nullable = true)
#  |-- ERICH5: double (nullable = true)
#  |-- LEUTX: double (nullable = true)
#  |-- PACSIN2: double (nullable = true)
#  |-- RFXAP: double (nullable = true)
#  |-- POGZ: double (nullable = true)
#  |-- LINC01271: double (nullable = true)
#  |-- OR6N2: double (nullable = true)
#  |-- MIR6859-4: double (nullable = true)
#  |-- HDAC3: double (nullable = true)
#  |-- RPS6KB2: double (nullable = true)
#  |-- RESF1: double (nullable = true)
#  |-- IL31RA: double (nullable = true)
#  |-- OR8K1: double (nullable = true)
#  |-- LINC02459: double (nullable = true)
#  |-- KHSRP: double (nullable = true)
#  |-- LINC01304: double (nullable = true)
#  |-- FLJ40194: double (nullable = true)
#  |-- FAM95C: double (nullable = true)
#  |-- HK3: double (nullable = true)
#  |-- ZG16B: double (nullable = true)
#  |-- MCMDC2: double (nullable = true)
#  |-- VSNL1: double (nullable = true)
#  |-- IDI2-AS1: double (nullable = true)
#  |-- MSR1: double (nullable = true)
#  |-- LOC105377623: double (nullable = true)
#  |-- NAT10: double (nullable = true)
#  |-- CHRNA2: double (nullable = true)
#  |-- WDR20: double (nullable = true)
#  |-- ZNF558: double (nullable = true)
#  |-- PML: double (nullable = true)
#  |-- ZNF813: double (nullable = true)
#  |-- SLC16A5: double (nullable = true)
#  |-- SFTPB: double (nullable = true)
#  |-- KRT23: double (nullable = true)
#  |-- SLC9B2: double (nullable = true)
#  |-- MOB2: double (nullable = true)
#  |-- ZBTB8OS: double (nullable = true)
#  |-- EEFSEC: double (nullable = true)
#  |-- NPSR1: double (nullable = true)
#  |-- ZNF570: double (nullable = true)
#  |-- LINC01226: double (nullable = true)
#  |-- HIST1H2BD: double (nullable = true)
#  |-- NAPG: double (nullable = true)
#  |-- JPH4: double (nullable = true)
#  |-- RASA1: double (nullable = true)
#  |-- CEP97: double (nullable = true)
#  |-- LINC02104: double (nullable = true)
#  |-- RARRES3: double (nullable = true)
#  |-- SPTBN5: double (nullable = true)
#  |-- PAPPA2: double (nullable = true)
#  |-- SPIN2B: double (nullable = true)
#  |-- LOC729291: double (nullable = true)
#  |-- SCARA3: double (nullable = true)
#  |-- PRAMEF5: double (nullable = true)
#  |-- PDX1: double (nullable = true)
#  |-- DNAL4: double (nullable = true)
#  |-- NR3C2: double (nullable = true)
#  |-- MEIS2: double (nullable = true)
#  |-- DLX6-AS1: double (nullable = true)
#  |-- PRRG3: double (nullable = true)
#  |-- CDK16: double (nullable = true)
#  |-- GIMAP7: double (nullable = true)
#  |-- UCP3: double (nullable = true)
#  |-- ABCB5: double (nullable = true)
#  |-- INPP1: double (nullable = true)
#  |-- GBP4: double (nullable = true)
#  |-- PDHB: double (nullable = true)
#  |-- RPL34: double (nullable = true)
#  |-- PRKCG: double (nullable = true)
#  |-- TRIM16L: double (nullable = true)
#  |-- ATIC: double (nullable = true)
#  |-- GIMAP2: double (nullable = true)
#  |-- CGNL1: double (nullable = true)
#  |-- TMEM43: double (nullable = true)
#  |-- FAM228A: double (nullable = true)
#  |-- ZNF682: double (nullable = true)
#  |-- ARHGDIA: double (nullable = true)
#  |-- ST5: double (nullable = true)
#  |-- ZNF107: double (nullable = true)
#  |-- LYPLAL1: double (nullable = true)
#  |-- UBE2U: double (nullable = true)
#  |-- PICALM: double (nullable = true)
#  |-- LINC00665: double (nullable = true)
#  |-- LOC284344: double (nullable = true)
#  |-- FBXO30: double (nullable = true)
#  |-- LOC103352541: double (nullable = true)
#  |-- ERP44: double (nullable = true)
#  |-- PLCG1-AS1: double (nullable = true)
#  |-- KLHL42: double (nullable = true)
#  |-- MSI2: double (nullable = true)
#  |-- MRPS5: double (nullable = true)
#  |-- MTO1: double (nullable = true)
#  |-- NCF1: double (nullable = true)
#  |-- FOXQ1: double (nullable = true)
#  |-- TMEM240: double (nullable = true)
#  |-- LINC02262: double (nullable = true)
#  |-- TBC1D17: double (nullable = true)
#  |-- LINC00489: double (nullable = true)
#  |-- LRRC23: double (nullable = true)
#  |-- KCNAB1: double (nullable = true)
#  |-- ZNRD1ASP: double (nullable = true)
#  |-- FREM1: double (nullable = true)
#  |-- TDRD3: double (nullable = true)
#  |-- RAB27A: double (nullable = true)
#  |-- LILRA1: double (nullable = true)
#  |-- ARHGAP11A: double (nullable = true)
#  |-- OR8J3: double (nullable = true)
#  |-- DIPK1C: double (nullable = true)
#  |-- NUDCD3: double (nullable = true)
#  |-- SLX4IP: double (nullable = true)
#  |-- C16orf87: double (nullable = true)
#  |-- LOC105374988: double (nullable = true)
#  |-- CST3: double (nullable = true)
#  |-- CALML3-AS1: double (nullable = true)
#  |-- TAF6: double (nullable = true)
#  |-- ZNF462: double (nullable = true)
#  |-- SLC27A4: double (nullable = true)
#  |-- SGK3: double (nullable = true)
#  |-- PAPOLG: double (nullable = true)
#  |-- AGA: double (nullable = true)
#  |-- LOC102725080: double (nullable = true)
#  |-- SERPINB9: double (nullable = true)
#  |-- PKN2-AS1: double (nullable = true)
#  |-- NTSR1: double (nullable = true)
#  |-- MIR22HG: double (nullable = true)
#  |-- ESR2: double (nullable = true)
#  |-- DCAF5: double (nullable = true)
#  |-- CYLC1: double (nullable = true)
#  |-- NAPEPLD: double (nullable = true)
#  |-- ZNF681: double (nullable = true)
#  |-- SSSCA1: double (nullable = true)
#  |-- SNORC: double (nullable = true)
#  |-- IL6: double (nullable = true)
#  |-- EFNB3: double (nullable = true)
#  |-- MIR4426: double (nullable = true)
#  |-- MEG9: double (nullable = true)
#  |-- LINC01675: double (nullable = true)
#  |-- MIR4472-1: double (nullable = true)
#  |-- RASAL1: double (nullable = true)
#  |-- CSN2: double (nullable = true)
#  |-- ATP13A2: double (nullable = true)
#  |-- IFITM3: double (nullable = true)
#  |-- PLPP2: double (nullable = true)
#  |-- WFDC21P: double (nullable = true)
#  |-- CTSD: double (nullable = true)
#  |-- RPL38: double (nullable = true)
#  |-- CHST9: double (nullable = true)
#  |-- NDUFB2: double (nullable = true)
#  |-- LNPK: double (nullable = true)
#  |-- NALCN-AS1: double (nullable = true)
#  |-- MACO1: double (nullable = true)
#  |-- TMIE: double (nullable = true)
#  |-- SPACA1: double (nullable = true)
#  |-- KIR3DL3: double (nullable = true)
#  |-- XYLT1: double (nullable = true)
#  |-- RGS2: double (nullable = true)
#  |-- ZNF516: double (nullable = true)
#  |-- LINC01494: double (nullable = true)
#  |-- PGLYRP3: double (nullable = true)
#  |-- SEMA6C: double (nullable = true)
#  |-- HERPUD2: double (nullable = true)
#  |-- SOX5: double (nullable = true)
#  |-- LOC102724152: double (nullable = true)
#  |-- NLRP10: double (nullable = true)
#  |-- LINC00511: double (nullable = true)
#  |-- ZNF710: double (nullable = true)
#  |-- MAPT-AS1: double (nullable = true)
#  |-- SLC1A2: double (nullable = true)
#  |-- ZHX2: double (nullable = true)
#  |-- SLC8A1: double (nullable = true)
#  |-- CAPZA2: double (nullable = true)
#  |-- LYAR: double (nullable = true)
#  |-- OR4D11: double (nullable = true)
#  |-- MIR6127: double (nullable = true)
#  |-- OR13C9: double (nullable = true)
#  |-- BCL6B: double (nullable = true)
#  |-- KCNB2: double (nullable = true)
#  |-- ATF5: double (nullable = true)
#  |-- ARHGAP44: double (nullable = true)
#  |-- BRD3: double (nullable = true)
#  |-- FDX1: double (nullable = true)
#  |-- ESRG: double (nullable = true)
#  |-- FRG1JP: double (nullable = true)
#  |-- HOXD3: double (nullable = true)
#  |-- ZNF44: double (nullable = true)
#  |-- COQ4: double (nullable = true)
#  |-- MIR4422HG: double (nullable = true)
#  |-- sample_id: string (nullable = true)
#  |-- sample_type: string (nullable = true)
#  |-- disease_type: string (nullable = true)
#  |-- primary_diagnosis: string (nullable = true)
#  |-- case_id: string (nullable = true)

# %%
# group columns by label, identifier and feature
label_columns = ['sample_type', 'disease_type', 'primary_diagnosis']
identifier_columns = ['_c0','sample_id','case_id']
feature_columns = [x for x in df.columns if x not in (label_columns+identifier_columns)]

# %%
# convert features into (sparse) vectors
assembler = VectorAssembler(inputCols=feature_columns, outputCol='features')
df = assembler.transform(df)
df=df.drop(*feature_columns)
# eventually we should store/load from HDFS

# %%
# convert string labels to numerical labels
# keep track of the column names of numerical labels
label_idx_columns = [s + '_idx' for s in label_columns]

# declare indexers for 3 columns
labelIndexer = [StringIndexer(inputCol=column, outputCol=column+'_idx',handleInvalid="error",
                              stringOrderType="frequencyDesc") for column in label_columns ]
# pipeline is needed to process a list of 3 labels
pipeline = Pipeline(stages=labelIndexer)
# transform 3 label columns from string to number catagoies 
df = pipeline.fit(df).transform(df)

# create dictionary containing 3 label lists
label_dict = {c.name: c.metadata["ml_attr"]["vals"]
for c in df.schema.fields if c.name.endswith("_idx")}

# %%
# Standardization 
scaler = StandardScaler(inputCol='features', outputCol='scaledFeatures', withStd=True, withMean=True)

# # Convert indexed labels back to original labels
labelConverter = IndexToString(inputCol="prediction", outputCol="predictedLabel",
                               labels=label_dict['disease_type_idx'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-74231d575764> in <module>
#       1 # Standardization
# ----> 2 scaler = StandardScaler(inputCol='features', outputCol='scaledFeatures', withStd=True, withMean=False)
#       3
#       4 # # Convert indexed labels back to original labels
#       5 labelConverter = IndexToString(inputCol="prediction", outputCol="predictedLabel",
#
# NameError: name 'StandardScaler' is not defined

# %%
# Evaluators
f1_evaluator=MulticlassClassificationEvaluator(predictionCol="prediction",labelCol='disease_type_idx', metricName='f1')
acc_evaluator=MulticlassClassificationEvaluator(predictionCol="prediction",labelCol='disease_type_idx', metricName='accuracy')
precision_evaluator=MulticlassClassificationEvaluator(predictionCol="prediction",labelCol='disease_type_idx', metricName='weightedPrecision')
recall_evaluator=MulticlassClassificationEvaluator(predictionCol="prediction",labelCol='disease_type_idx', metricName='weightedRecall')

# %%
# test/train split
Xtest,Xtrain = df.randomSplit([0.3, 0.7], seed)

# %%
# save sample_ids of split

# %%
# stdmodel = scaler.fit(Xtrain)
modelPath = "full_cpv_standard-scaler-model"
# stdmodel.save(modelPath)
from pyspark.ml.feature import StandardScalerModel
stdmodel = StandardScalerModel.load(modelPath)

# %% [markdown]
# ### Binary Logistic Regression - cancer/no-cancer classification

# %%
Xtrain = stdmodel.transform(Xtrain)
Xtest = stdmodel.transform(Xtest)
# loadedModel = StandardScalerModel.load(modelPath)

# %%
# to save
# df.rdd.saveAsPickleFile(filename)
# to load
#pickleRdd = sc.pickleFile(filename).collect()
# df2 = spark.createDataFrame(pickleRdd)

# %%
# Logistic Regression model 
lr = LogisticRegression(aggregationDepth= 3,maxIter=100, regParam=0.4, elasticNetParam=0.5,
                        featuresCol='scaledFeatures',labelCol ='disease_type_idx',
                       family='multinomial',tol=1e-06)

# Hyperparameters to test
paramGrid = ParamGridBuilder().addGrid(lr.regParam, [0.1,0.4])\
            .build()

# K-fold cross validation 
crossval = CrossValidator(estimator=lr,
                          estimatorParamMaps=paramGrid,
                          evaluator=f1_evaluator,
                          numFolds=2,seed=seed)  # use 3+ folds in practice

# Put steps in a pipeline
pipeline = Pipeline(stages=[crossval])

# %%
# train model
pipModel = pipeline.fit(Xtrain)

# %%
# get hyperparameters for best model
cvModel = pipModel.stages[-1]
bestParams = cvModel.extractParamMap()
# print ('Best Param (regParam): ', bestModel._java_obj.getRegParam())
bestModel = cvModel.bestModel
coeff = bestModel.coefficientMatrix
intercept = bestModel.interceptVector
trainingSummary = bestModel.summary
# save model
# bestModel.save('cpv1600_logistic')

# %%
# predict
predictions = pipModel.transform(Xtest)

# %%
# Convert indexed labels back to original labels.
labelConverter = IndexToString(inputCol="prediction", outputCol="predictedLabel",
                               labels=label_dict['disease_type_idx'])
predictions = labelConverter.transform(predictions)

# %%
f1_score = f1_evaluator.evaluate(predictions)
acc_score = acc_evaluator.evaluate(predictions)
precision_score = precision_evaluator.evaluate(predictions)
recall_score = recall_evaluator.evaluate(predictions)
print(f1_score)
print(acc_score)
print(precision_score)
print(recall_score)

# %%
trainingSummary = bestModel.summary
objectiveHistory = trainingSummary.objectiveHistory
getTrainingMetrics(trainingSummary)

# %%
# predictions.select("disease_type","predictedLabel","disease_type_idx","prediction","rawPrediction","probability").show(2)

# %% [markdown]
# ### Random Forest

# %%
# test/train split
Xtest,Xtrain = df.randomSplit([0.3, 0.7], seed)

# %%
from pyspark.ml.classification import RandomForestClassifier
# Random Forest Classifier
rf = RandomForestClassifier(cacheNodeIds=True, featuresCol='percentFeatures',labelCol ='disease_type_idx', numTrees=200,\
                           seed=seed,)


# # Hyperparameters to test
paramGrid = ParamGridBuilder().addGrid(rf.maxDepth, [5])\
            .build()

# # K-fold cross validation 
crossval = CrossValidator(estimator=rf,
                          estimatorParamMaps=paramGrid,
                          evaluator=f1_evaluator,
                          numFolds=5,seed=seed)  # use 3+ folds in practice

# # Put steps in a pipeline
pipeline = Pipeline(stages=[crossval])

# %%
# train model
pipModel = pipeline.fit(Xtrain)

# %%
# predict
predictions = pipModel.transform(Xtest)

# %%
# get hyperparameters for best model
cvModel = pipModel.stages[-1]
bestParams = cvModel.extractParamMap()
# print ('Best Param (regParam): ', bestModel._java_obj.getRegParam())
bestModel = cvModel.bestModel
feature_importance = bestModel.featureImportances
num_trees = bestModel.getNumTrees
tree_weights = bestModel.treeWeights
trees =  bestModel.trees
# trainingSummary = bestModel.summary
# objectiveHistory = trainingSummary.objectiveHistory
# save model
bestModel.save('cpv1600_rf')
# getTrainingMetrics(trainingSummary)

# %%
# Convert indexed labels back to original labels.
labelConverter = IndexToString(inputCol="prediction", outputCol="predictedLabel",
                               labels=label_dict['disease_type_idx'])
predictions = labelConverter.transform(predictions)

# %%
f1_score = f1_evaluator.evaluate(predictions)
acc_score = acc_evaluator.evaluate(predictions)
precision_score = precision_evaluator.evaluate(predictions)
recall_score = recall_evaluator.evaluate(predictions)
print(f1_score)
print(acc_score)
print(precision_score)
print(recall_score)

# %% [markdown]
# ### Gradient Boosted Tree

# %%
# test/train split
Xtest,Xtrain = df.randomSplit([0.3, 0.7], seed)

# %%
from pyspark.ml.classification import GBTClassifier
# Random Forest Classifier
gbt = GBTClassifier(labelCol="disease_type_idx", featuresCol="percentFeatures", cacheNodeIds=True, maxIter=1000,\
                   seed = seed, stepSize=0.2, maxDepth=5)



# # Hyperparameters to test
paramGrid = ParamGridBuilder().addGrid(gbt.maxDepth, [5])\
            .build()

# # K-fold cross validation 
crossval = CrossValidator(estimator=gbt,
                          estimatorParamMaps=paramGrid,
                          evaluator=f1_evaluator,
                          numFolds=2,seed=seed)  # use 3+ folds in practice

# # Put steps in a pipeline
pipeline = Pipeline(stages=[crossval])

# %%
# train model
pipModel = pipeline.fit(Xtrain)
# predict
predictions = pipModel.transform(Xtest)

# %%
# get hyperparameters for best model
cvModel = pipModel.stages[-1]
bestParams = cvModel.extractParamMap()
# print ('Best Param (regParam): ', bestModel._java_obj.getRegParam())
bestModel = cvModel.bestModel
feature_importance = bestModel.featureImportances
num_trees = bestModel.getNumTrees
tree_weights = bestModel.treeWeights
# trees =  bestModel.trees
# trainingSummary = bestModel.summary
# objectiveHistory = trainingSummary.objectiveHistory
# getTrainingMetrics(trainingSummary)
# save model
bestModel.save('cpv1600_gbt')

# %%
f1_score = f1_evaluator.evaluate(predictions)
acc_score = acc_evaluator.evaluate(predictions)
precision_score = precision_evaluator.evaluate(predictions)
recall_score = recall_evaluator.evaluate(predictions)

# %%
print(f1_score)
print(acc_score)
print(precision_score)
print(recall_score)

# %%
import urllib
sparkHost = "sparky"

for x in range(4040,4060):
    link = "http://"+sparkHost+":"+str(x)+"/environment/"
    try:
        f = urllib.request.urlopen(link)
        myfile = f.read()
        if (sc.applicationId in str(myfile)):
            print ('Application ID found on port ', x)
    except:
        pass

# %% [markdown]
# ### Feature Selection

# %%
# feature selection by top percentile
from pyspark.ml.feature import ChiSqSelector

p_selector = ChiSqSelector(numTopFeatures=5000,outputCol="percentFeatures",featuresCol="scaledFeatures",labelCol="disease_type_idx")
p_selector_model = p_selector.fit(Xtrain)

# # feature seleciton by false-positive-rate threshold
# f_selector = ChiSqSelector(selectorType = 'fpr', fpr=0.2, outputCol="fprFeatures",featuresCol="features",labelCol="disease_type_idx")
# f_selector_model = f_selector.fit(XTrain)

# %%
modelPath2 = "full_cpv_p-select-5000-model"
p_selector_model.save(modelPath2)

# %%
print("Percent Selecter:", p_selector.getNumTopFeatures())
Xtrain=p_selector_model.transform(Xtrain)
Xtest=p_selector_model.transform(Xtest)
# print("FPR Selecter:", f_selector.getNumTopFeatures())

# %%
sel_idx = p_selector_model.selectedFeatures

# %%
def save(fpath,fname,obj):
    # selector saver 
    fullpath = fpath + '/'+ fname
    obj.save(fullpath)

# def load(fpath):
#     # selector loader
#     loadedSelector = ChiSqSelector.load(chiSqSelectorPath)
#     loadedSelector.getNumTopFeatures() == selector.getNumTopFeatures()
#     # model loader
#     loadedModel = ChiSqSelectorModel.load(modelPath)
#     loadedModel.selectedFeatures == model.selectedFeatures

# %%
cwd = os.getcwd()
save(cwd,'cpv_toy_10percent_chi_selector',p_selector)
save(cwd,'cpv_toy_10percent_chi_model',p_selector_model)
save(cwd,'cpv_toy_2fpr_chi_selector',f_selector)
save(cwd,'cpv_toy_2fpr_model',f_selector_model)

# %% [markdown]
# ### Logistic Regerssion for Cancer/No Cancer

# %%
# Extract the summary from the returned LogisticRegressionModel instance trained
# in the earlier example
trainingSummary = lrModel.summary

# Obtain the objective per iteration
objectiveHistory = trainingSummary.objectiveHistory
print("objectiveHistory:")
for objective in objectiveHistory:
    print(objective)

# Obtain the receiver-operating characteristic as a dataframe and areaUnderROC.
trainingSummary.roc.show()
print("areaUnderROC: " + str(trainingSummary.areaUnderROC))

# Set the model threshold to maximize F-Measure
fMeasure = trainingSummary.fMeasureByThreshold
maxFMeasure = fMeasure.groupBy().max('F-Measure').select('max(F-Measure)').head()
bestThreshold = fMeasure.where(fMeasure['F-Measure'] == maxFMeasure['max(F-Measure)']).select('threshold').head()['threshold']
lr.setThreshold(bestThreshold)
print("setting model to best threshold:"+ str(bestThreshold))

# %% [markdown]
# ### Logistic Regression for Multi-class

# %%
# We can also use the multinomial family for binary classification
mlr = LogisticRegression(maxIter=1000, regParam=0.3, elasticNetParam=0.8, family="multinomial",featuresCol='scaledFeatures',labelCol ='disease_type_idx')

# Fit the model
mlrModel = mlr.fit(XyTrain_disease)

# Print the coefficients and intercepts for logistic regression with multinomial family
print("Multinomial coefficients: " + str(mlrModel.coefficientMatrix))
print("Multinomial intercepts: " + str(mlrModel.interceptVector))

# Extract the summary from the returned LogisticRegressionModel instance trained
# in the earlier example
trainingSummary = lrModel.summary

# Obtain the objective per iteration
objectiveHistory = trainingSummary.objectiveHistory
print("objectiveHistory:")
for objective in objectiveHistory:
    print(objective)

# Obtain the receiver-operating characteristic as a dataframe and areaUnderROC.
trainingSummary.roc.show()
print("areaUnderROC: " + str(trainingSummary.areaUnderROC))

# Set the model threshold to maximize F-Measure
fMeasure = trainingSummary.fMeasureByThreshold
maxFMeasure = fMeasure.groupBy().max('F-Measure').select('max(F-Measure)').head()
bestThreshold = fMeasure.where(fMeasure['F-Measure'] == maxFMeasure['max(F-Measure)']).select('threshold').head()['threshold']
lr.setThreshold(bestThreshold)
print("setting model to best threshold:"+ str(bestThreshold))
